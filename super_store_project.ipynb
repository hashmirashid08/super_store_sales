# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
dataset=pd.read_excel('super_store2.xlsx')
dataset['Order Month']=dataset['Order Date'].dt.month

# %%
dataset
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %% [markdown]
# # Missing Values:

# %%
dataset.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# Order Month      0
# dtype: int64

# %%
sns.barplot(x="Ship Mode", y= "Sales",data = dataset)
plt.title("Sales delivered by different shipping modes")
# Out:
# Text(0.5, 1.0, 'Sales delivered by different shipping modes')

# %%
dataset.shape
# Out:
# (9994, 21)

# %% [markdown]
# # Ship Mode

# %%
x=dataset['Ship Mode'].value_counts().index
y=dataset['Ship Mode'].value_counts().values

# %%
plt.figure(figsize=(4,4))
plt.pie(y,labels=x,startangle=0,autopct="%0.2f%%")
plt.legend(loc=1)

# %%
sns.countplot(x="Ship Mode",data=dataset,hue="Category")
# Out:
# <Axes: xlabel='Ship Mode', ylabel='count'>

# %% [markdown]
# # Sales Of different category

# %%
sns.barplot(x="Category",y="Sales", data=dataset)
# Out:
# <Axes: xlabel='Category', ylabel='Sales'>

# %% [markdown]
# # Total sales in different months

# %%
sns.barplot(x="Order Month",y="Sales", data=dataset)
plt.title("Total sales in different months")
# Out:
# Text(0.5, 1.0, 'Total sales in different months')

# %%
sns.barplot(x="Order Month",y="Sales",data=dataset,hue="Region")
# Out:
# <Axes: xlabel='Order Month', ylabel='Sales'>

# %%
sns.barplot(x="Order Month",y="Sales",hue="Category",data=dataset)
# Out:
# <Axes: xlabel='Order Month', ylabel='Sales'>

# %%
dataset.groupby(['State'])['Sales'].sum()
# Out:
# State
# Alabama                  19510.6400
# Arizona                  35282.0010
# Arkansas                 11678.1300
# California              457687.6315
# Colorado                 32108.1180
# Connecticut              13384.3570
# Delaware                 27451.0690
# District of Columbia      2865.0200
# Florida                  89473.7080
# Georgia                  49095.8400
# Idaho                     4382.4860
# Illinois                 80166.1010
# Indiana                  53555.3600
# Iowa                      4579.7600
# Kansas                    2914.3100
# Kentucky                 36591.7500
# Louisiana                 9217.0300
# Maine                     1270.5300
# Maryland                 23705.5230
# Massachusetts            28634.4340
# Michigan                 76269.6140
# Minnesota                29863.1500
# Mississippi              10771.3400
# Missouri                 22205.1500
# Montana                   5589.3520
# Nebraska                  7464.9300
# ...

# %%
df4=dataset.sort_values(by="Quantity",ascending=False)
df5=df4.groupby( [ "State", "Sub-Category"],as_index=True )['Quantity'].sum().to_frame(name = 'Quantity')
df6=df5.sort_values(by="Quantity",ascending=False)

# %%
var_1 = df6.groupby("State")
var_1
for x,y in var_1:
    print(x)
    print(y)
    print("apple")
# Out:
# Alabama
#                       Quantity
# State   Sub-Category
# Alabama Binders             41
#         Art                 38
#         Chairs              30
#         Paper               29
#         Accessories         24
#         Phones              18
#         Storage             14
#         Furnishings         12
#         Tables              12
#         Envelopes           11
#         Labels               8
#         Machines             8
#         Supplies             5
#         Copiers              3
#         Fasteners            2
#         Appliances           1
# apple
# Arizona
#                       Quantity
# State   Sub-Category
# Arizona Binders            155
#         Paper              124
#         Accessories         85
#         Furnishings         82
#         Phones              79
#         Storage             78
#         Chairs              52
#         Art                 47
#         Tables              36
#         Envelopes           28
# ...

# %%
df7=dataset.sort_values(by="Quantity",ascending=False)
df8=df7.groupby( [ "Order Month", "Sub-Category"],as_index=True )['Quantity'].sum().to_frame(name = 'Quantity')
df9=df8.sort_values(by="Quantity",ascending=False)

# %%
var_2 = df9.groupby("Order Month")
var_2
for x in var_2:
    print(x)
    print(y)
    print("apple")
# Out:
# (1,                           Quantity
# Order Month Sub-Category
# 1           Binders            244
#             Furnishings        184
#             Paper              184
#             Phones             132
#             Art                131
#             Storage            123
#             Accessories        111
#             Chairs              61
#             Tables              52
#             Bookcases           48
#             Envelopes           41
#             Appliances          40
#             Labels              39
#             Fasteners           32
#             Supplies            25
#             Machines            19
#             Copiers              9)
#                           Quantity
# Order Month Sub-Category
# 12          Binders            837
#             Paper              740
#             Furnishings        556
#             Accessories        469
#             Chairs             430
#             Phones             410
# ...

# %% [markdown]
# # Conclusion:-

# %% [markdown]
# In this project,we analyzed the dataset of a superstore.We checked if there are any null values in any of the column.Then we analyszed sales delivered by different shipping modes.

# %% [markdown]
# The data analysis reveals that the sales is highest int the month of March.We also found that the top selling sub-categories of the superstore in different months are Blinders, Papers and Furnishings and the top selling sub-categ0ries in different states which are different for different states which can be seen clearly by looking at the analysis.

# %% [markdown]
# So the company should focus to keep the stocks of the top seeling categories in the right location so that the products can be delivered easily, at low cost and at right time.
